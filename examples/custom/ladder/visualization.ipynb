# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
r_df = pd.read_csv('logs/cm_r2.csv')
r_df.head()
# Out:
#    result  win_method  pkmn_left  opp_pkmn_left  player_elo  opp_elo  turns  \
# 0       0           0          0              3        1000     1095     19
# 1       1          11          6              6        1000     1091      5
# 2       0           0          0              3        1050     1009     33
# 3       0           0          0              4        1030     1166     24
# 4       0           0          0              3        1021     1000     24
#
#     battle_id      date
# 0  1991805665  11_15_23
# 1  1991806564  11_15_23
# 2  1991806932  11_15_23
# 3  1991808497  11_15_23
# 4  1991809913  11_15_23

# %%
r_df
# Out:
#     result  win_method  pkmn_left  opp_pkmn_left  player_elo  opp_elo  turns  \
# 0        0           0          0              3        1000     1095     19
# 1        1          11          6              6        1000     1091      5
# 2        0           0          0              3        1050     1009     33
# 3        0           0          0              4        1030     1166     24
# 4        0           0          0              3        1021     1000     24
# 5        1          12          6              6        1007     1183      0
# 6        0           0          0              5        1064     1075     32
# 7        0           0          0              4        1045     1000     31
# 8        0           0          0              5        1026     1113     24
# 9        0           0          0              4        1016     1089     22
# 10       0           0          0              4        1006     1015     21
# 11       0           0          0              6        1000     1166     30
# 12       0           0          0              5        1000     1096     24
# 13       0           0          0              5        1000     1047     15
# 14       0           0          0              3        1000     1000     21
#
#      battle_id      date
# 0   1991805665  11_15_23
# 1   1991806564  11_15_23
# 2   1991806932  11_15_23
# 3   1991808497  11_15_23
# 4   1991809913  11_15_23
# 5   1991812091  11_16_23
# 6   1991812980  11_16_23
# 7   1991814419  11_16_23
# 8   1991815653  11_16_23
# 9   1991816648  11_16_23
# 10  1992215377  11_16_23
# 11  1992218931  11_16_23
# 12  1992221751  11_16_23
# 13  1992224682  11_16_23
# 14  1992225295  11_16_23

# %%
def get_report(df):
    f_df = df[~((df['turns'] < 1) | ((df['win_method'] == 11) & (df['opp_pkmn_left'] == 6)))]
    # df_filtered = df[(df['turns'] < 1) | (df['win_method'] == '11' & df['opp_pkmn_left'] == 6)]
    print("Total battles: ", len(f_df))
    print("Win rate: ", len(f_df[f_df['win_method'] == 1])/len(f_df))
    print("Average turns: ", f_df['turns'].mean())
    print("Average Pokemon left: ", f_df['pkmn_left'].mean())
    print("Average Opponent Pokemon left: ", f_df['opp_pkmn_left'].mean())
    print("Average Opponent Elo: ", f_df['opp_elo'].mean())
    return f_df

# %%
f_r_df = get_report(r_df)
f_r_df
# Out:
# Total battles:  13
# Win rate:  0.0
# Average turns:  24.615384615384617
# Average Pokemon left:  0.0
# Average Opponent Pokemon left:  4.153846153846154
# Average Opponent Elo:  1067.0
#     result  win_method  pkmn_left  opp_pkmn_left  player_elo  opp_elo  turns  \
# 0        0           0          0              3        1000     1095     19
# 2        0           0          0              3        1050     1009     33
# 3        0           0          0              4        1030     1166     24
# 4        0           0          0              3        1021     1000     24
# 6        0           0          0              5        1064     1075     32
# 7        0           0          0              4        1045     1000     31
# 8        0           0          0              5        1026     1113     24
# 9        0           0          0              4        1016     1089     22
# 10       0           0          0              4        1006     1015     21
# 11       0           0          0              6        1000     1166     30
# 12       0           0          0              5        1000     1096     24
# 13       0           0          0              5        1000     1047     15
# 14       0           0          0              3        1000     1000     21
#
#      battle_id      date
# 0   1991805665  11_15_23
# 2   1991806932  11_15_23
# 3   1991808497  11_15_23
# 4   1991809913  11_15_23
# 6   1991812980  11_16_23
# 7   1991814419  11_16_23
# 8   1991815653  11_16_23
# 9   1991816648  11_16_23
# 10  1992215377  11_16_23
# 11  1992218931  11_16_23
# 12  1992221751  11_16_23
# 13  1992224682  11_16_23
# 14  1992225295  11_16_23

# %%
sns.lineplot(x=list(range(1, len(r_df) + 1)), y=r_df["player_elo"])
plt.ylim(998, 1500)
# Out:
# (998.0, 1500.0)
